# %% [markdown]
# # Import Dependencies

# %%
# import dependencies
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# %matplotlib inline
from pymongo import MongoClient
from pprint import pprint
import joblib

# %% [markdown]
# # Load Data

# %%
# I will name the dataset data when it is loaded in
df = pd.read_csv("data_files/Model_Ready.csv")
df.head()
# Out:
#                         _id                  _id_game  game_id  \
# 0  664f7fde36cf90b9bbe8fbda  664f7ee136cf90b9bbe8c333     8787
# 1  664f7fde36cf90b9bbe8fbdb  664f7ee136cf90b9bbe8c334     8788
# 2  664f7fde36cf90b9bbe8fbdc  664f7ee136cf90b9bbe8c335     8789
# 3  664f7fde36cf90b9bbe8fbdd  664f7ee136cf90b9bbe8c336     8790
# 4  664f7fde36cf90b9bbe8fbde  664f7ee136cf90b9bbe8c337     8791
#
#                  date_start           visitor_name visitor_nickname  \
# 0  2021-10-19T23:30:00.000Z          Brooklyn Nets             Nets
# 1  2021-10-20T02:00:00.000Z  Golden State Warriors         Warriors
# 2  2021-10-20T23:00:00.000Z         Indiana Pacers           Pacers
# 3  2021-10-20T23:00:00.000Z          Chicago Bulls            Bulls
# 4  2021-10-20T23:30:00.000Z         Boston Celtics          Celtics
#
#   visitor_code  home_id           home_name home_nickname  ... home_defReb  \
# 0          BKN       21     Milwaukee Bucks         Bucks  ...          41
# 1          GSW       17  Los Angeles Lakers        Lakers  ...          40
# 2          IND        5   Charlotte Hornets       Hornets  ...          34
# 3          CHI       10     Detroit Pistons       Pistons  ...          36
# 4          BOS       24     New York Knicks        Knicks  ...          48
#
#    home_totReb  home_assists home_pFouls  home_steals  home_turnovers  \
# 0           54            25          19            8               7
# 1           45            21          25            7              17
# 2           46            29          21            9               8
# 3           47            17          16            7              16
# 4           55            27          22            9              17
#
#    home_blocks  home_plusMinus  Over/Under  Result
# 0            9              23       240.5   Under
# 1            4              -7       229.0    Over
# 2            5               1       228.5    Over
# 3            5              -6       218.0   Under
# 4           10               4       219.5    Over
#
# [5 rows x 54 columns]

# %% [markdown]
# # Prepare Data for Encoding

# %%
df.columns
# Out:
# Index(['_id', '_id_game', 'game_id', 'date_start', 'visitor_name',
#        'visitor_nickname', 'visitor_code', 'home_id', 'home_name',
#        'home_nickname', 'home_code', 'visitor_points_game', 'home_points_game',
#        '_id_stats', 'visitor_points_stats', 'visitor_fgm', 'visitor_fga',
#        'visitor_fgp', 'visitor_ftm', 'visitor_fta', 'visitor_ftp',
#        'visitor_tpm', 'visitor_tpa', 'visitor_tpp', 'visitor_offReb',
#        'visitor_defReb', 'visitor_totReb', 'visitor_assists', 'visitor_pFouls',
#        'visitor_steals', 'visitor_turnovers', 'visitor_blocks',
#        'visitor_plusMinus', 'home_points_stats', 'home_fgm', 'home_fga',
#        'home_fgp', 'home_ftm', 'home_fta', 'home_ftp', 'home_tpm', 'home_tpa',
#        'home_tpp', 'home_offReb', 'home_defReb', 'home_totReb', 'home_assists',
#        'home_pFouls', 'home_steals', 'home_turnovers', 'home_blocks',
#        'home_plusMinus', 'Over/Under', 'Result'],
#       dtype='object')

# %%
newdf = df[['home_name','visitor_name','home_points_game','visitor_points_game','home_totReb','visitor_totReb','home_assists','visitor_assists','home_blocks','visitor_blocks','Over/Under','Result']]

# %%
newdf.rename(columns={'Over/Under':'over_under'})
# Out:
#                 home_name           visitor_name  home_points_game  \
# 0         Milwaukee Bucks          Brooklyn Nets               127
# 1      Los Angeles Lakers  Golden State Warriors               114
# 2       Charlotte Hornets         Indiana Pacers               123
# 3         Detroit Pistons          Chicago Bulls                88
# 4         New York Knicks         Boston Celtics               138
# ...                   ...                    ...               ...
# 2120       Boston Celtics    Cleveland Cavaliers               120
# 2121       Boston Celtics    Cleveland Cavaliers                94
# 2122  Cleveland Cavaliers         Boston Celtics                93
# 2123  Cleveland Cavaliers         Boston Celtics               102
# 2124       Boston Celtics    Cleveland Cavaliers               113
#
#       visitor_points_game  home_totReb  visitor_totReb  home_assists  \
# 0                     104           54              44            25
# 1                     121           45              50            21
# 2                     122           46              51            29
# 3                      94           47              48            17
# 4                     134           55              56            27
# ...                   ...          ...             ...           ...
# 2120                   95           55              38            22
# 2121                  118           31              44            22
# 2122                  106           35              44            17
# 2123                  109           32              48            26
# 2124                   98           43              28            32
#
#       visitor_assists  home_blocks  visitor_blocks  over_under Result
# 0                  19            9               9       240.5  Under
# 1                  30            4               2       229.0   Over
# 2                  29            5              10       228.5   Over
# 3                  18            5               5       218.0  Under
# 4                  34           10               9       219.5   Over
# ...               ...          ...             ...         ...    ...
# 2120               19            7               3       208.5   Over
# 2121               24            3               3       212.0  Under
# 2122               22            2               4       211.0  Under
# 2123               15            3               4       208.0   Over
# 2124               25            6               2       205.5   Over
#
# [2125 rows x 12 columns]

# %%
newdf['total_score'] = newdf['home_points_game'] + newdf['visitor_points_game']
# Out:
# C:\Users\Latasha Jones\AppData\Local\Temp\ipykernel_29776\1845410676.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['total_score'] = newdf['home_points_game'] + newdf['visitor_points_game']

# %%
newdf.count()
# Out:
# home_name              2125
# visitor_name           2125
# home_points_game       2125
# visitor_points_game    2125
# home_totReb            2125
# visitor_totReb         2125
# home_assists           2125
# visitor_assists        2125
# home_blocks            2125
# visitor_blocks         2125
# Over/Under             2125
# Result                 2125
# total_score            2125
# dtype: int64

# %%
# Updating target column to True/False values
newdf['Result'].replace('Under',0,inplace=True)
newdf['Result'].replace('Over',1,inplace=True)
# Out:
# C:\Users\Latasha Jones\AppData\Local\Temp\ipykernel_29776\2546420923.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Result'].replace('Under',0,inplace=True)
# C:\Users\Latasha Jones\AppData\Local\Temp\ipykernel_29776\2546420923.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['Result'].replace('Over',1,inplace=True)

# %%
newdf
# Out:
#                 home_name           visitor_name  home_points_game  \
# 0         Milwaukee Bucks          Brooklyn Nets               127
# 1      Los Angeles Lakers  Golden State Warriors               114
# 2       Charlotte Hornets         Indiana Pacers               123
# 3         Detroit Pistons          Chicago Bulls                88
# 4         New York Knicks         Boston Celtics               138
# ...                   ...                    ...               ...
# 2120       Boston Celtics    Cleveland Cavaliers               120
# 2121       Boston Celtics    Cleveland Cavaliers                94
# 2122  Cleveland Cavaliers         Boston Celtics                93
# 2123  Cleveland Cavaliers         Boston Celtics               102
# 2124       Boston Celtics    Cleveland Cavaliers               113
#
#       visitor_points_game  home_totReb  visitor_totReb  home_assists  \
# 0                     104           54              44            25
# 1                     121           45              50            21
# 2                     122           46              51            29
# 3                      94           47              48            17
# 4                     134           55              56            27
# ...                   ...          ...             ...           ...
# 2120                   95           55              38            22
# 2121                  118           31              44            22
# 2122                  106           35              44            17
# 2123                  109           32              48            26
# 2124                   98           43              28            32
#
#       visitor_assists  home_blocks  visitor_blocks  Over/Under  Result  \
# 0                  19            9               9       240.5       0
# 1                  30            4               2       229.0       1
# 2                  29            5              10       228.5       1
# 3                  18            5               5       218.0       0
# 4                  34           10               9       219.5       1
# ...               ...          ...             ...         ...     ...
# 2120               19            7               3       208.5       1
# 2121               24            3               3       212.0       0
# 2122               22            2               4       211.0       0
# 2123               15            3               4       208.0       1
# 2124               25            6               2       205.5       1
#
#       total_score
# 0             231
# 1             235
# 2             245
# 3             182
# 4             272
# ...           ...
# 2120          215
# 2121          212
# 2122          199
# 2123          211
# 2124          211
#
# [2125 rows x 13 columns]

# %% [markdown]
# # Prepocess and Encode Data

# %%
# encode the columns (run this column only if needed)
dummies = pd.get_dummies(newdf, columns=['home_name','visitor_name'])
dummies.head()
# Out:
#    home_points_game  visitor_points_game  home_totReb  visitor_totReb  \
# 0               127                  104           54              44
# 1               114                  121           45              50
# 2               123                  122           46              51
# 3                88                   94           47              48
# 4               138                  134           55              56
#
#    home_assists  visitor_assists  home_blocks  visitor_blocks  Over/Under  \
# 0            25               19            9               9       240.5
# 1            21               30            4               2       229.0
# 2            29               29            5              10       228.5
# 3            17               18            5               5       218.0
# 4            27               34           10               9       219.5
#
#    Result  ...  visitor_name_Oklahoma City Thunder  \
# 0       0  ...                               False
# 1       1  ...                               False
# 2       1  ...                               False
# 3       0  ...                               False
# 4       1  ...                               False
#
#    visitor_name_Orlando Magic  visitor_name_Philadelphia 76ers  \
# 0                       False                            False
# 1                       False                            False
# 2                       False                            False
# 3                       False                            False
# 4                       False                            False
#
#    visitor_name_Phoenix Suns  visitor_name_Portland Trail Blazers  \
# 0                      False                                False
# 1                      False                                False
# 2                      False                                False
# 3                      False                                False
# 4                      False                                False
#
#    visitor_name_Sacramento Kings  visitor_name_San Antonio Spurs  \
# 0                          False                           False
# 1                          False                           False
# 2                          False                           False
# 3                          False                           False
# 4                          False                           False
#
#    visitor_name_Toronto Raptors  visitor_name_Utah Jazz  \
# 0                         False                   False
# 1                         False                   False
# 2                         False                   False
# 3                         False                   False
# 4                         False                   False
#
#    visitor_name_Washington Wizards
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
# [5 rows x 71 columns]

# %%
X = dummies.copy()
X.drop("Result",axis=1,inplace=True)
X.head()
# Out:
#    home_points_game  visitor_points_game  home_totReb  visitor_totReb  \
# 0               127                  104           54              44
# 1               114                  121           45              50
# 2               123                  122           46              51
# 3                88                   94           47              48
# 4               138                  134           55              56
#
#    home_assists  visitor_assists  home_blocks  visitor_blocks  Over/Under  \
# 0            25               19            9               9       240.5
# 1            21               30            4               2       229.0
# 2            29               29            5              10       228.5
# 3            17               18            5               5       218.0
# 4            27               34           10               9       219.5
#
#    total_score  ...  visitor_name_Oklahoma City Thunder  \
# 0          231  ...                               False
# 1          235  ...                               False
# 2          245  ...                               False
# 3          182  ...                               False
# 4          272  ...                               False
#
#    visitor_name_Orlando Magic  visitor_name_Philadelphia 76ers  \
# 0                       False                            False
# 1                       False                            False
# 2                       False                            False
# 3                       False                            False
# 4                       False                            False
#
#    visitor_name_Phoenix Suns  visitor_name_Portland Trail Blazers  \
# 0                      False                                False
# 1                      False                                False
# 2                      False                                False
# 3                      False                                False
# 4                      False                                False
#
#    visitor_name_Sacramento Kings  visitor_name_San Antonio Spurs  \
# 0                          False                           False
# 1                          False                           False
# 2                          False                           False
# 3                          False                           False
# 4                          False                           False
#
#    visitor_name_Toronto Raptors  visitor_name_Utah Jazz  \
# 0                         False                   False
# 1                         False                   False
# 2                         False                   False
# 3                         False                   False
# 4                         False                   False
#
#    visitor_name_Washington Wizards
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
#
# [5 rows x 70 columns]

# %%
X.columns
# Out:
# Index(['home_points_game', 'visitor_points_game', 'home_totReb',
#        'visitor_totReb', 'home_assists', 'visitor_assists', 'home_blocks',
#        'visitor_blocks', 'Over/Under', 'total_score',
#        'home_name_Atlanta Hawks', 'home_name_Boston Celtics',
#        'home_name_Brooklyn Nets', 'home_name_Charlotte Hornets',
#        'home_name_Chicago Bulls', 'home_name_Cleveland Cavaliers',
#        'home_name_Dallas Mavericks', 'home_name_Denver Nuggets',
#        'home_name_Detroit Pistons', 'home_name_Golden State Warriors',
#        'home_name_Houston Rockets', 'home_name_Indiana Pacers',
#        'home_name_LA Clippers', 'home_name_Los Angeles Lakers',
#        'home_name_Memphis Grizzlies', 'home_name_Miami Heat',
#        'home_name_Milwaukee Bucks', 'home_name_Minnesota Timberwolves',
#        'home_name_New Orleans Pelicans', 'home_name_New York Knicks',
#        'home_name_Oklahoma City Thunder', 'home_name_Orlando Magic',
#        'home_name_Philadelphia 76ers', 'home_name_Phoenix Suns',
#        'home_name_Portland Trail Blazers', 'home_name_Sacramento Kings',
#        'home_name_San Antonio Spurs', 'home_name_Toronto Raptors',
#        'home_name_Utah Jazz', 'home_name_Washington Wizards',
#        'visitor_name_Atlanta Hawks', 'visitor_name_Boston Celtics',
#        'visitor_name_Brooklyn Nets', 'visitor_name_Charlotte Hornets',
#        'visitor_name_Chicago Bulls', 'visitor_name_Cleveland Cavaliers',
#        'visitor_name_Dallas Mavericks', 'visitor_name_Denver Nuggets',
#        'visitor_name_Detroit Pistons', 'visitor_name_Golden State Warriors',
#        'visitor_name_Houston Rockets', 'visitor_name_Indiana Pacers',
#        'visitor_name_LA Clippers', 'visitor_name_Los Angeles Lakers',
#        'visitor_name_Memphis Grizzlies', 'visitor_name_Miami Heat',
#        'visitor_name_Milwaukee Bucks', 'visitor_name_Minnesota Timberwolves',
#        'visitor_name_New Orleans Pelicans', 'visitor_name_New York Knicks',
#        'visitor_name_Oklahoma City Thunder', 'visitor_name_Orlando Magic',
#        'visitor_name_Philadelphia 76ers', 'visitor_name_Phoenix Suns',
#        'visitor_name_Portland Trail Blazers', 'visitor_name_Sacramento Kings',
#        'visitor_name_San Antonio Spurs', 'visitor_name_Toronto Raptors',
#        'visitor_name_Utah Jazz', 'visitor_name_Washington Wizards'],
#       dtype='object')

# %%
y = dummies['Result'].values.reshape(-1,1)

# %% [markdown]
# # Split, Train, Scale Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Creating StandardScaler instance
scaler = StandardScaler()

# %%
# Fitting Standard Scaller
X_scaler = scaler.fit(X_train)

# %%
# Scaling data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Fit the Random Forest Model

# %%
# Create a random forest classifier
rf_model = RandomForestClassifier(n_estimators=1000, random_state=78)

# %%
# Fit the model and use .ravel()on the "y_train" data. 
rf_model = rf_model.fit(X_train_scaled, y_train.ravel())

# %% [markdown]
# # Make Predictions Using the Random Forest Model

# %%
# Making predictions using the testing data
predictions = rf_model.predict(X_test_scaled)

# %% [markdown]
# # Model Evaluation

# %%
# Calculating the confusion matrix
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(
    cm, index=["Actual 0", "Actual 1"], columns=["Predicted 0", "Predicted 1"]
)

# Calculating the accuracy score
acc_score = accuracy_score(y_test, predictions)

# %%
# Displaying results
print("Confusion Matrix")
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0          236           22
# Actual 1           16          258
# Accuracy Score : 0.9285714285714286
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       258
#            1       0.92      0.94      0.93       274
#
#     accuracy                           0.93       532
#    macro avg       0.93      0.93      0.93       532
# weighted avg       0.93      0.93      0.93       532

# %% [markdown]
# # Feature Importance

# %%
# get important features
importances = rf_model.feature_importances_

#sort by importance
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.263911543779023, 'total_score'),
#  (0.13835752991607672, 'home_points_game'),
#  (0.1342473648853736, 'visitor_points_game'),
#  (0.1255574798839996, 'Over/Under'),
#  (0.045813832590131484, 'visitor_assists'),
#  (0.04003547512244925, 'home_assists'),
#  (0.03865522060547239, 'visitor_totReb'),
#  (0.03433152704005456, 'home_totReb'),
#  (0.02429271093908601, 'visitor_blocks'),
#  (0.022095700022961018, 'home_blocks'),
#  (0.0035148697223629437, 'home_name_Boston Celtics'),
#  (0.0033256972233217694, 'visitor_name_Washington Wizards'),
#  (0.0033025154250490344, 'home_name_Charlotte Hornets'),
#  (0.002999068207595925, 'home_name_Washington Wizards'),
#  (0.002812466544895079, 'visitor_name_Cleveland Cavaliers'),
#  (0.002785126991811563, 'home_name_Chicago Bulls'),
#  (0.0027752342581710042, 'visitor_name_San Antonio Spurs'),
#  (0.0027537170280764957, 'home_name_Portland Trail Blazers'),
#  (0.0026784467704680744, 'visitor_name_New Orleans Pelicans'),
#  (0.0026637195848113566, 'home_name_Indiana Pacers'),
#  (0.002605289407717212, 'home_name_Oklahoma City Thunder'),
#  (0.0025941184114246256, 'visitor_name_Golden State Warriors'),
#  (0.0025400137668839967, 'visitor_name_Brooklyn Nets'),
#  (0.0025199039322063637, 'visitor_name_Chicago Bulls'),
#  (0.00251248626067389, 'visitor_name_Milwaukee Bucks'),
#  (0.002489625207628872, 'visitor_name_Houston Rockets'),
#  (0.002473087313038187, 'visitor_name_Philadelphia 76ers'),
#  (0.0024534388053779324, 'home_name_Miami Heat'),
#  (0.002445044278832796, 'home_name_New York Knicks'),
#  (0.0024449379998841354, 'visitor_name_Denver Nuggets'),
#  (0.00244185834142553, 'visitor_name_Indiana Pacers'),
#  (0.0024234498290797587, 'visitor_name_Miami Heat'),
#  (0.0023043884057530714, 'visitor_name_Charlotte Hornets'),
#  (0.0021807117363040612, 'home_name_Cleveland Cavaliers'),
#  (0.002177330306515128, 'visitor_name_Orlando Magic'),
#  (0.0021642208644550446, 'home_name_Orlando Magic'),
#  (0.002160995976793224, 'home_name_Philadelphia 76ers'),
#  (0.002159483369672669, 'home_name_Houston Rockets'),
#  (0.002127619636374726, 'home_name_Toronto Raptors'),
#  (0.0021240146986745527, 'home_name_Milwaukee Bucks'),
#  (0.0021153442844817284, 'visitor_name_Memphis Grizzlies'),
#  (0.002091457699377242, 'visitor_name_Boston Celtics'),
#  (0.002087403825506039, 'visitor_name_Portland Trail Blazers'),
#  (0.00208657004567468, 'home_name_Phoenix Suns'),
#  (0.002081567053010752, 'home_name_Minnesota Timberwolves'),
#  (0.0020763757249291017, 'home_name_Atlanta Hawks'),
#  (0.002057233376774974, 'visitor_name_Minnesota Timberwolves'),
#  (0.002052200022825046, 'visitor_name_Oklahoma City Thunder'),
#  (0.0019897830634756073, 'home_name_Dallas Mavericks'),
#  (0.0019788342613583656, 'home_name_Denver Nuggets'),
#  (0.001957237597609886, 'home_name_New Orleans Pelicans'),
#  (0.0019456378758958743, 'visitor_name_Phoenix Suns'),
#  (0.0019217736938810857, 'home_name_Brooklyn Nets'),
#  (0.001914978158430397, 'visitor_name_New York Knicks'),
#  (0.0019141875157625608, 'home_name_San Antonio Spurs'),
#  (0.0018550031980236693, 'visitor_name_LA Clippers'),
#  (0.0018460873220649146, 'visitor_name_Toronto Raptors'),
#  (0.001843004510581963, 'visitor_name_Sacramento Kings'),
#  (0.0018136662073382692, 'visitor_name_Utah Jazz'),
#  (0.0018070460202665565, 'visitor_name_Dallas Mavericks'),
#  (0.0017307309257148533, 'home_name_Sacramento Kings'),
#  (0.0017195177402564228, 'visitor_name_Detroit Pistons'),
#  (0.0017175539940556758, 'home_name_Los Angeles Lakers'),
#  (0.0017114878210138628, 'home_name_Memphis Grizzlies'),
#  (0.0016942147929096068, 'home_name_Detroit Pistons'),
#  (0.001692885322409455, 'visitor_name_Los Angeles Lakers'),
#  (0.001643178331787239, 'home_name_Utah Jazz'),
#  (0.001619548901402284, 'home_name_LA Clippers'),
#  (0.0014705151278677005, 'home_name_Golden State Warriors'),
#  (0.0013137104954076503, 'visitor_name_Atlanta Hawks')]

# %%
# # save the model to a pickle file
# sports_bet_model = "sports_bet_model.pkl"

# # save the scaler to a pickle file
# joblib.dump(scaler, "scaler.pkl")
